# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Athlete_events.csv')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df = df.sort_values(['Year'], ascending ='false', axis= 0)
df.head()
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 214333  107607  Fritz Richard Gustav Schuft   M  19.0     NaN     NaN
# 244717  122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN
# 244716  122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN
# 23912    12563    Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23913    12563    Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
#
#            Team  NOC        Games  Year  Season    City       Sport  \
# 214333  Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 244717   France  FRA  1896 Summer  1896  Summer  Athina   Athletics
# 244716   France  FRA  1896 Summer  1896  Summer  Athina   Athletics
# 23912   Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 23913   Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
#
#                                    Event   Medal
# 214333  Gymnastics Men's Pommelled Horse     NaN
# ...

# %%
df.tail()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 142355   71419  Luis Fernando Lpez Erazo   M  37.0   166.0    60.0
# 47729    24610          Enrico D'Aniello   M  20.0   152.0    53.0
# 47728    24609          Sabrina D'Angelo   F  23.0   173.0    71.0
# 47746    24621  Andrea Mitchell D'Arrigo   M  21.0   194.0    85.0
# 236646  118650             Blair Tarrant   M  26.0   185.0    83.0
#
#                Team  NOC        Games  Year  Season            City  \
# 142355     Colombia  COL  2016 Summer  2016  Summer  Rio de Janeiro
# 47729         Italy  ITA  2016 Summer  2016  Summer  Rio de Janeiro
# 47728        Canada  CAN  2016 Summer  2016  Summer  Rio de Janeiro
# 47746         Italy  ITA  2016 Summer  2016  Summer  Rio de Janeiro
# 236646  New Zealand  NZL  2016 Summer  2016  Summer  Rio de Janeiro
#
#             Sport                                Event   Medal
# 142355  Athletics   Athletics Men's 20 kilometres Walk     NaN
# ...

# %%
JK= df['Sex'].value_counts()
print('Jenis Kelamin dalam perhelatan Olimpiade musim panas 1896-2016 =', JK)
# Out:
# Jenis Kelamin dalam perhelatan Olimpiade musim panas 1896-2016 = M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
dfa = df.sort_values(['Age', 'Year'], ascending = 'False', axis=0)
dfa.head()
# Out:
#             ID                                             Name Sex   Age  \
# 142882   71691                               Dimitrios Loundras   M  10.0
# 94058    47618       Sonja Henie (-Topping, -Gardiner, -Onstad)   F  11.0
# 79024    40129                                 Luigina Giavotti   F  11.0
# 237141  118925  Megan Olwen Devenish Taylor (-Mandeville-Ellis)   F  11.0
# 43468    22411                       Magdalena Cecilia Colledge   F  11.0
#
#         Height  Weight                           Team  NOC        Games  Year  \
# 142882     NaN     NaN  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896
# 94058    155.0    45.0                         Norway  NOR  1924 Winter  1924
# 79024      NaN     NaN                          Italy  ITA  1928 Summer  1928
# 237141   157.0     NaN                  Great Britain  GBR  1932 Winter  1932
# 43468    152.0     NaN                  Great Britain  GBR  1932 Winter  1932
#
#         Season         City           Sport  \
# ...

# %%
dfm = df.sort_values(['Age', 'Year','Medal'], ascending = False, axis=0)
dfm.head()
# Out:
#             ID                        Name Sex   Age  Height  Weight  \
# 257054  128719      John Quincy Adams Ward   M  97.0     NaN     NaN
# 98118    49663               Winslow Homer   M  96.0     NaN     NaN
# 60862    31173  Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# 60863    31173  Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
# 60861    31173  Thomas Cowperthwait Eakins   M  88.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season         City  \
# 257054  United States  USA  1928 Summer  1928  Summer    Amsterdam
# 98118   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 60862   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 60863   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 60861   United States  USA  1932 Summer  1932  Summer  Los Angeles
#
#                    Sport                                           Event Medal
# ...

# %%
df = df.fillna({'Medal':'None'})
df.head()
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 214333  107607  Fritz Richard Gustav Schuft   M  19.0     NaN     NaN
# 244717  122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN
# 244716  122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN
# 23912    12563    Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23913    12563    Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
#
#            Team  NOC        Games  Year  Season    City       Sport  \
# 214333  Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 244717   France  FRA  1896 Summer  1896  Summer  Athina   Athletics
# 244716   France  FRA  1896 Summer  1896  Summer  Athina   Athletics
# 23912   Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 23913   Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
#
#                                    Event   Medal
# 214333  Gymnastics Men's Pommelled Horse    None
# ...

# %%
medal = pd.get_dummies(df['Medal'])

# %%
medal.head()
# Out:
#         Bronze  Gold  None  Silver
# 214333       0     0     1       0
# 244717       0     0     0       1
# 244716       0     0     1       0
# 23912        0     0     1       0
# 23913        0     0     1       0

# %%
df= df.join(medal)
df.head()
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 214333  107607  Fritz Richard Gustav Schuft   M  19.0     NaN     NaN
# 244717  122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN
# 244716  122526      Pierre Alexandre Tuffri   M  19.0     NaN     NaN
# 23912    12563    Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23913    12563    Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
#
#            Team  NOC        Games  Year  Season    City       Sport  \
# 214333  Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 244717   France  FRA  1896 Summer  1896  Summer  Athina   Athletics
# 244716   France  FRA  1896 Summer  1896  Summer  Athina   Athletics
# 23912   Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
# 23913   Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
#
#                                    Event   Medal  Bronze  Gold  None  Silver
# ...

# %%
dfn = df.sort_values(['None','Age'], ascending = False, axis= 0)
dfn.head(2)
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
# 98118    49663           Winslow Homer   M  96.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season         City  \
# 257054  United States  USA  1928 Summer  1928  Summer    Amsterdam
# 98118   United States  USA  1932 Summer  1932  Summer  Los Angeles
#
#                    Sport                                           Event  \
# 257054  Art Competitions     Art Competitions Mixed Sculpturing, Statues
# 98118   Art Competitions  Art Competitions Mixed Painting, Unknown Event
#
#        Medal  Bronze  Gold  None  Silver
# 257054  None       0     0     1       0
# 98118   None       0     0     1       0

# %%
dfg= df.sort_values(['Gold','Age'], ascending=False, axis= 0)
dfg.head(2)
# Out:
#             ID               Name Sex   Age  Height  Weight           Team  \
# 105199   53238    Charles Jacobus   M  64.0     NaN     NaN  United States
# 233390  117046  Oscar Gomer Swahn   M  64.0     NaN     NaN         Sweden
#
#         NOC        Games  Year  Season       City     Sport  \
# 105199  USA  1904 Summer  1904  Summer  St. Louis     Roque
# 233390  SWE  1912 Summer  1912  Summer  Stockholm  Shooting
#
#                                                    Event Medal  Bronze  Gold  \
# 105199                               Roque Men's Singles  Gold       0     1
# 233390  Shooting Men's Running Target, Single Shot, Team  Gold       0     1
#
#         None  Silver
# 105199     0       0
# 233390     0       0

# %%
dfs=df.sort_values(['Silver','Age'], ascending=False, axis=0)
dfs.head(2)
# Out:
#             ID                                           Name Sex   Age  \
# 44584    22984  John (Herbert Crawford-) Copley (Williamson-)   M  73.0
# 233395  117046                              Oscar Gomer Swahn   M  72.0
#
#         Height  Weight           Team  NOC        Games  Year  Season  \
# 44584      NaN     NaN  Great Britain  GBR  1948 Summer  1948  Summer
# 233395     NaN     NaN         Sweden  SWE  1920 Summer  1920  Summer
#
#              City             Sport  \
# 44584      London  Art Competitions
# 233395  Antwerpen          Shooting
#
#                                                    Event   Medal  Bronze  \
# 44584      Art Competitions Mixed Painting, Graphic Arts  Silver       0
# 233395  Shooting Men's Running Target, Double Shot, Team  Silver       0
#
#         Gold  None  Silver
# 44584      0     0       1
# 233395     0     0       1

# %%
dfb=df.sort_values(['Bronze','Age'], ascending=False, axis=0)
dfb.head(2)
# Out:
#            ID                    Name Sex   Age  Height  Weight        Team  \
# 60009   30731              Jozu Dupon   M  72.0     NaN     NaN     Belgium
# 150756  75648  Charles William Martin   M  71.0     NaN     NaN  Crabe II-4
#
#         NOC        Games  Year  Season    City             Sport  \
# 60009   BEL  1936 Summer  1936  Summer  Berlin  Art Competitions
# 150756  FRA  1900 Summer  1900  Summer   Paris           Sailing
#
#                                              Event   Medal  Bronze  Gold  \
# 60009   Art Competitions Mixed Sculpturing, Medals  Bronze       1     0
# 150756                     Sailing Mixed 0.5-1 Ton  Bronze       1     0
#
#         None  Silver
# 60009      0       0
# 150756     0       0

# %%
df['Sport'].value_counts()
# Out:
# Athletics                    38624
# Gymnastics                   26707
# Swimming                     23195
# Shooting                     11448
# Cycling                      10859
# Fencing                      10735
# Rowing                       10595
# Cross Country Skiing          9133
# Alpine Skiing                 8829
# Wrestling                     7154
# Football                      6745
# Sailing                       6586
# Equestrianism                 6344
# Canoeing                      6171
# Boxing                        6047
# Speed Skating                 5613
# Ice Hockey                    5516
# Hockey                        5417
# Biathlon                      4893
# Basketball                    4536
# Weightlifting                 3937
# Water Polo                    3846
# Judo                          3801
# Handball                      3665
# Art Competitions              3578
# Volleyball                    3404
# Bobsleigh                     3058
# ...

# %%
INA_CON = df[df['NOC']=='INA']
INA_CON.head()
# Out:
#             ID                                   Name Sex   Age  Height  \
# 231738  116250                          Habib Suharko   M  23.0     NaN
# 231556  116170                       Maram Sudarmodjo   M  24.0     NaN
# 238793  119715                         Thio Ging Hwie   M  28.0     NaN
# 238794  119716                        Thio Him Tjiang   M  27.0     NaN
# 82975    42145  Johannes Edouard Willem "Jalal" Gozal   M  20.0   162.0
#
#         Weight       Team  NOC        Games  Year  Season       City  \
# 231738     NaN  Indonesia  INA  1952 Summer  1952  Summer   Helsinki
# 231556     NaN  Indonesia  INA  1952 Summer  1952  Summer   Helsinki
# 238793    67.0  Indonesia  INA  1952 Summer  1952  Summer   Helsinki
# 238794     NaN  Indonesia  INA  1956 Summer  1956  Summer  Melbourne
# 82975     57.0  Indonesia  INA  1956 Summer  1956  Summer  Melbourne
#
#                 Sport                                   Event Medal  Bronze  \
# ...

# %%
all_go = pd.DataFrame(df.groupby(['Team','NOC', 'Medal'])['Medal'].size())
all_go.head()
# Out:
#                                   Medal
# Team                  NOC Medal
# 30. Februar           AUT None        2
# A North American Team MEX Bronze      3
#                       USA Bronze      1
# Acipactli             MEX None        3
# Acturus               ARG None        2

# %%
all_go.columns = ['Total']
all_go.head()
# Out:
#                                   Total
# Team                  NOC Medal
# 30. Februar           AUT None        2
# A North American Team MEX Bronze      3
#                       USA Bronze      1
# Acipactli             MEX None        3
# Acturus               ARG None        2

# %%
all_go = all_go.reset_index()
all_go.head()
# Out:
#                     Team  NOC   Medal  Total
# 0            30. Februar  AUT    None      2
# 1  A North American Team  MEX  Bronze      3
# 2  A North American Team  USA  Bronze      1
# 3              Acipactli  MEX    None      3
# 4                Acturus  ARG    None      2

# %%
all_go['None'] = np.where(all_go['Medal']=='None', all_go['Total'],0)
all_go['G'] = np.where(all_go['Medal']=='Gold', all_go['Total'],0)
all_go['S'] = np.where(all_go['Medal']=='Silver', all_go['Total'],0)
all_go['B'] = np.where(all_go['Medal']== 'Bronze', all_go['Total'],0)
all_go.head()
# Out:
#                     Team  NOC   Medal  Total  None  G  S  B
# 0            30. Februar  AUT    None      2     2  0  0  0
# 1  A North American Team  MEX  Bronze      3     0  0  0  3
# 2  A North American Team  USA  Bronze      1     0  0  0  1
# 3              Acipactli  MEX    None      3     3  0  0  0
# 4                Acturus  ARG    None      2     2  0  0  0

# %%
all_go = all_go.groupby('NOC').sum().reset_index().sort_values(by=['G','S','B'], ascending = False)
all_go.head()
# Out:
#      NOC  Total   None     G     S     B
# 216  USA  18853  13216  2638  1641  1358
# 214  URS   5685   3182  1082   732   689
# 79   GER   9830   7665   745   674   746
# 74   GBR  12256  10188   678   739   651
# 100  ITA  10715   9078   575   531   531

# %%
all_go['Total Medal'] = all_go['Total']-all_go['None']
all_go.head()
# Out:
#      NOC  Total   None     G     S     B  Total Medal
# 216  USA  18853  13216  2638  1641  1358         5637
# 214  URS   5685   3182  1082   732   689         2503
# 79   GER   9830   7665   745   674   746         2165
# 74   GBR  12256  10188   678   739   651         2068
# 100  ITA  10715   9078   575   531   531         1637

# %%
all_go['Total Medal'].sum()
# Out:
# 39783

# %%
a = all_go['G'].sum()
a
# Out:
# 13372

# %%
b = all_go['S'].sum()
b
# Out:
# 13116

# %%
c = all_go['B'].sum()
c
# Out:
# 13295

# %%
all_part = pd.DataFrame(df['Sport'].value_counts())
all_part.head()
# Out:
#             Sport
# Athletics   38624
# Gymnastics  26707
# Swimming    23195
# Shooting    11448
# Cycling     10859

# %%
all_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 230 entries, 216 to 226
# Data columns (total 7 columns):
# NOC            230 non-null object
# Total          230 non-null int64
# None           230 non-null int64
# G              230 non-null int64
# S              230 non-null int64
# B              230 non-null int64
# Total Medal    230 non-null int64
# dtypes: int64(6), object(1)
# memory usage: 14.4+ KB

# %%
INA = all_go[all_go['NOC']=='INA']
INA.head()
# Out:
#     NOC  Total  None   G   S   B  Total Medal
# 91  INA    412   371  11  17  13           41

# %%
df16=df[df['Year']==2016]
df16.head()
# Out:
#             ID                  Name Sex   Age  Height  Weight  \
# 221333  111237  Nitendra Singh Rawat   M  29.0   172.0    58.0
# 112439   56939      Mantas Kalnietis   M  29.0   195.0    90.0
# 266669  133402           Yuan Xinyue   F  19.0   201.0    78.0
# 156630   78679       Elisa Meneghini   F  19.0   150.0    42.0
# 7908      4379             Rami Anis   M  25.0   178.0    78.0
#
#                             Team  NOC        Games  Year  Season  \
# 221333                     India  IND  2016 Summer  2016  Summer
# 112439                 Lithuania  LTU  2016 Summer  2016  Summer
# 266669                     China  CHN  2016 Summer  2016  Summer
# 156630                     Italy  ITA  2016 Summer  2016  Summer
# 7908    Refugee Olympic Athletes  ROT  2016 Summer  2016  Summer
#
#                   City       Sport                                Event Medal  \
# 221333  Rio de Janeiro   Athletics             Athletics Men's Marathon  None
# ...

# %%
INA16_CON = df16[df16['NOC']=='INA']
INA16_CON
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 266742  133444             Dewi Yuliawati   F  19.0   166.0    65.0
# 9158      5039             I Ketut Ariana   M  26.0   167.0    69.0
# 202232  101574     Ika Yuliana Rochmawati   F  27.0   165.0    52.0
# 156403   78547                       Memo   M  21.0   192.0    88.0
# 266076  133115    Yessy Venisia Yosaputra   F  21.0   167.0    62.0
# 190783   95832              Greysia Polii   F  28.0   163.0    56.0
# 66415    33967          Lindaweni Fanetri   F  26.0   167.0    60.0
# 110521   55884             Praveen Jordan   M  23.0   183.0    88.0
# 61604    31541            Riau Ega Agatha   M  24.0   175.0    70.0
# 61603    31541            Riau Ega Agatha   M  24.0   175.0    70.0
# 2453      1374              Tontowi Ahmad   M  29.0   179.0    72.0
# 2331      1301      Sri Wahyuni Agustiani   F  21.0   147.0    47.0
# 2591      1451             Mohammad Ahsan   M  28.0   173.0    72.0
# ...

# %%
all_go16 = pd.DataFrame(df16.groupby(['Team','NOC', 'Medal'])['Medal'].size())
all_go16.head()
# Out:
#                            Medal
# Team           NOC Medal
# Afghanistan    AFG None        3
# Albania        ALB None        6
# Algeria        ALG None       72
#                    Silver      2
# American Samoa ASA None        4

# %%
all_go16.columns = ['Total']
all_go16.head()
# Out:
#                            Total
# Team           NOC Medal
# Afghanistan    AFG None        3
# Albania        ALB None        6
# Algeria        ALG None       72
#                    Silver      2
# American Samoa ASA None        4

# %%
all_go16 = all_go16.reset_index()
all_go16.head()
# Out:
#              Team  NOC   Medal  Total
# 0     Afghanistan  AFG    None      3
# 1         Albania  ALB    None      6
# 2         Algeria  ALG    None     72
# 3         Algeria  ALG  Silver      2
# 4  American Samoa  ASA    None      4

# %%
all_go16['None']= np.where(all_go16['Medal']=='None', all_go16['Total'],0)
all_go16['G']= np.where(all_go16['Medal']=='Gold', all_go16['Total'],0)
all_go16['S']= np.where(all_go16['Medal']=='Silver', all_go16['Total'],0)
all_go16['B']= np.where(all_go16['Medal']=='Bronze', all_go16['Total'],0)
all_go16.head()
# Out:
#              Team  NOC   Medal  Total  None  G  S  B
# 0     Afghanistan  AFG    None      3     3  0  0  0
# 1         Albania  ALB    None      6     6  0  0  0
# 2         Algeria  ALG    None     72    72  0  0  0
# 3         Algeria  ALG  Silver      2     0  0  2  0
# 4  American Samoa  ASA    None      4     4  0  0  0

# %%
all_go16 = all_go16.groupby('NOC').sum().reset_index().sort_values(by=['G','S','B'], ascending=False)
all_go16.head()
# Out:
#      NOC  Total  None    G   S   B
# 198  USA    719   455  139  54  71
# 68   GBR    478   333   64  55  26
# 159  RUS    406   291   52  28  35
# 72   GER    536   377   49  43  67
# 38   CHN    499   386   46  30  37

# %%
all_go16['Total Medal'] = all_go16['Total'] - all_go16['None']
all_go16.head()
# Out:
#      NOC  Total  None    G   S   B  Total Medal
# 198  USA    719   455  139  54  71          264
# 68   GBR    478   333   64  55  26          145
# 159  RUS    406   291   52  28  35          115
# 72   GER    536   377   49  43  67          159
# 38   CHN    499   386   46  30  37          113

# %%
all_go16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207 entries, 198 to 206
# Data columns (total 7 columns):
# NOC            207 non-null object
# Total          207 non-null int64
# None           207 non-null int64
# G              207 non-null int64
# S              207 non-null int64
# B              207 non-null int64
# Total Medal    207 non-null int64
# dtypes: int64(6), object(1)
# memory usage: 12.9+ KB

# %%
INA16 = all_go16[all_go16['NOC']=='INA']
INA16.head()
# Out:
#     NOC  Total  None  G  S  B  Total Medal
# 84  INA     31    27  2  2  0            4
